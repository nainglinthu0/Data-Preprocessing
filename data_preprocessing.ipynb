# %% [markdown]
# # Assignement 1 - Data Importing and Preprocessing

# %% [markdown]
# Visit here to download the dataset - https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data?select=train.csv
# it is compettion dataset, so must jon the competition first and then download and locate it in your workspace.

# %%
import pandas as pd
df=pd.read_csv(r'train.csv')
df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 6         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 7         Lvl    AllPub  ...        0    NaN    NaN        Shed     350
# 8         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 9         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
# 5     10   2009        WD         Normal     143000
# 6      8   2007        WD         Normal     307000
# 7     11   2009        WD         Normal     200000
# 8      4   2008        WD        Abnorml     129900
# 9      1   2008        WD         Normal     118000
#
# [10 rows x 81 columns]

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# # Code here to see only numeric and also only categorical

# %% [markdown]
# #Numerical Data

# %%
numerical_columns = df.select_dtypes(include='number')
print("\nFirst 10 rows of numeric columns:")
print(numerical_columns.head(10))
# Out:
# First 10 rows of numeric columns:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
# 5   6          50         85.0    14115            5            5       1993
# 6   7          20         75.0    10084            8            5       2004
# 7   8          60          NaN    10382            7            6       1973
# 8   9          50         51.0     6120            7            5       1931
# 9  10         190         50.0     7420            5            6       1939
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
# 5          1995         0.0         732  ...          40           30
# 6          2005       186.0        1369  ...         255           57
# 7          1973       240.0         859  ...         235          204
# 8          1950         0.0           0  ...          90            0
# 9          1950         0.0         851  ...           0            4
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# 0              0          0            0         0        0       2    2008
# 1              0          0            0         0        0       5    2007
# 2              0          0            0         0        0       9    2008
# 3            272          0            0         0        0       2    2006
# 4              0          0            0         0        0      12    2008
# 5              0        320            0         0      700      10    2009
# 6              0          0            0         0        0       8    2007
# 7            228          0            0         0      350      11    2009
# 8            205          0            0         0        0       4    2008
# 9              0          0            0         0        0       1    2008
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000
# 5     143000
# 6     307000
# 7     200000
# 8     129900
# 9     118000
#
# [10 rows x 38 columns]

# %% [markdown]
# #Categorical Data

# %%
categorical_columns = df.select_dtypes(include='object')
print("\nFirst 10 rows of categorical columns:")
print(categorical_columns.head(10))
# Out:
# First 10 rows of categorical columns:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# 5       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 6       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 7       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 8       RM   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 9       RL   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
#
#   Neighborhood Condition1  ... GarageType GarageFinish GarageQual GarageCond  \
# 0      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 1      Veenker      Feedr  ...     Attchd          RFn         TA         TA
# 2      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 3      Crawfor       Norm  ...     Detchd          Unf         TA         TA
# 4      NoRidge       Norm  ...     Attchd          RFn         TA         TA
# 5      Mitchel       Norm  ...     Attchd          Unf         TA         TA
# 6      Somerst       Norm  ...     Attchd          RFn         TA         TA
# 7       NWAmes       PosN  ...     Attchd          RFn         TA         TA
# 8      OldTown     Artery  ...     Detchd          Unf         Fa         TA
# 9      BrkSide     Artery  ...     Attchd          RFn         Gd         TA
#
#   PavedDrive PoolQC  Fence MiscFeature SaleType SaleCondition
# 0          Y    NaN    NaN         NaN       WD        Normal
# 1          Y    NaN    NaN         NaN       WD        Normal
# 2          Y    NaN    NaN         NaN       WD        Normal
# 3          Y    NaN    NaN         NaN       WD       Abnorml
# 4          Y    NaN    NaN         NaN       WD        Normal
# 5          Y    NaN  MnPrv        Shed       WD        Normal
# 6          Y    NaN    NaN         NaN       WD        Normal
# 7          Y    NaN    NaN        Shed       WD        Normal
# 8          Y    NaN    NaN         NaN       WD       Abnorml
# 9          Y    NaN    NaN         NaN       WD        Normal
#
# [10 rows x 43 columns]

# %% [markdown]
# # Check is there are missing values
# #### Try somethings to these missing values 1) ignore 2) remove 3)replace (with contastan,staticial data, using some ML algorithms)
# #### make sure after doing something, you other content will remain unchanged. For example, if you drop null, it might lose other contents of the column because it remvoes the whole rows. Please make sure before and after dropping the null values if you chose to remove

# %%
print("Missing values before any processing:")
print(df.isnull().sum())
# Out:
# Missing values before any processing:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# #If we decide to remove,...

# %%
print("Missing values before processing:")
print(df.isnull().sum())
# Out:
# Missing values before processing:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
numerical_columns = df.select_dtypes(include='number').columns
df_filled = df.copy()
df_filled[numerical_columns] = df[numerical_columns].fillna(df[numerical_columns].median())

# %%
categorical_columns = df.select_dtypes(include='object').columns
df_filled[categorical_columns] = df[categorical_columns].fillna(df[categorical_columns].mode().iloc[0])

# %%
print("\nMissing values after replacing:")
print(df_filled.isnull().sum())
# Out:
# Missing values after replacing:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
print("\nFirst few rows after replacing missing values:")
print(df_filled.head(10))
# Out:
# First few rows after replacing missing values:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  Grvl      Reg
# 1   2          20       RL         80.0     9600   Pave  Grvl      Reg
# 2   3          60       RL         68.0    11250   Pave  Grvl      IR1
# 3   4          70       RL         60.0     9550   Pave  Grvl      IR1
# 4   5          60       RL         84.0    14260   Pave  Grvl      IR1
# 5   6          50       RL         85.0    14115   Pave  Grvl      IR1
# 6   7          20       RL         75.0    10084   Pave  Grvl      Reg
# 7   8          60       RL         69.0    10382   Pave  Grvl      IR1
# 8   9          50       RM         51.0     6120   Pave  Grvl      Reg
# 9  10         190       RL         50.0     7420   Pave  Grvl      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
# 1         Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
# 2         Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
# 3         Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
# 4         Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
# 5         Lvl    AllPub  ...        0     Gd  MnPrv        Shed     700
# 6         Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
# 7         Lvl    AllPub  ...        0     Gd  MnPrv        Shed     350
# 8         Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
# 9         Lvl    AllPub  ...        0     Gd  MnPrv        Shed       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
# 5     10   2009        WD         Normal     143000
# 6      8   2007        WD         Normal     307000
# 7     11   2009        WD         Normal     200000
# 8      4   2008        WD        Abnorml     129900
# 9      1   2008        WD         Normal     118000
#
# [10 rows x 81 columns]

# %% [markdown]
# # Check how many rows we have

# %%
rows_before_processing = df.shape[0]
rows_before_processing
# Out:
# 1460

# %% [markdown]
# # Check how many columns we have

# %%
len(df.columns)
# Out:
# 81

# %% [markdown]
# # Will you use all columns to work on, Or we can choose the most relevant columns from it. You can decide the number.

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
selected_columns = ['OverallQual', 'GrLivArea', 'TotRmsAbvGrd', 'LotArea', 'YearBuilt', 'Neighborhood', 'HouseStyle', 'GarageType', 'SaleCondition', 'SalePrice']
selected_df = df[selected_columns]
selected_df.head(10)
# Out:
#    OverallQual  GrLivArea  TotRmsAbvGrd  LotArea  YearBuilt Neighborhood  \
# 0            7       1710             8     8450       2003      CollgCr
# 1            6       1262             6     9600       1976      Veenker
# 2            7       1786             6    11250       2001      CollgCr
# 3            7       1717             7     9550       1915      Crawfor
# 4            8       2198             9    14260       2000      NoRidge
# 5            5       1362             5    14115       1993      Mitchel
# 6            8       1694             7    10084       2004      Somerst
# 7            7       2090             7    10382       1973       NWAmes
# 8            7       1774             8     6120       1931      OldTown
# 9            5       1077             5     7420       1939      BrkSide
#
#   HouseStyle GarageType SaleCondition  SalePrice
# 0     2Story     Attchd        Normal     208500
# 1     1Story     Attchd        Normal     181500
# 2     2Story     Attchd        Normal     223500
# 3     2Story     Detchd       Abnorml     140000
# 4     2Story     Attchd        Normal     250000
# 5     1.5Fin     Attchd        Normal     143000
# 6     1Story     Attchd        Normal     307000
# 7     2Story     Attchd        Normal     200000
# 8     1.5Fin     Detchd       Abnorml     129900
# 9     1.5Unf     Attchd        Normal     118000

# %%
#Let's check data types of your column
selected_df.dtypes
# Out:
# OverallQual       int64
# GrLivArea         int64
# TotRmsAbvGrd      int64
# LotArea           int64
# YearBuilt         int64
# Neighborhood     object
# HouseStyle       object
# GarageType       object
# SaleCondition    object
# SalePrice         int64
# dtype: object

# %%
selected_df.dtypes.value_counts()
# Out:
# int64     6
# object    4
# Name: count, dtype: int64

# %%
# Use some encoding techniques here for your categoical data
encoded_df = pd.get_dummies(selected_df, columns=['Neighborhood', 'HouseStyle', 'GarageType', 'SaleCondition'], drop_first=True)
encoded_df.head(10)
# Out:
#    OverallQual  GrLivArea  TotRmsAbvGrd  LotArea  YearBuilt  SalePrice  \
# 0            7       1710             8     8450       2003     208500
# 1            6       1262             6     9600       1976     181500
# 2            7       1786             6    11250       2001     223500
# 3            7       1717             7     9550       1915     140000
# 4            8       2198             9    14260       2000     250000
# 5            5       1362             5    14115       1993     143000
# 6            8       1694             7    10084       2004     307000
# 7            7       2090             7    10382       1973     200000
# 8            7       1774             8     6120       1931     129900
# 9            5       1077             5     7420       1939     118000
#
#    Neighborhood_Blueste  Neighborhood_BrDale  Neighborhood_BrkSide  \
# 0                 False                False                 False
# 1                 False                False                 False
# 2                 False                False                 False
# 3                 False                False                 False
# 4                 False                False                 False
# 5                 False                False                 False
# 6                 False                False                 False
# 7                 False                False                 False
# 8                 False                False                 False
# 9                 False                False                  True
#
#    Neighborhood_ClearCr  ...  GarageType_Attchd  GarageType_Basment  \
# 0                 False  ...               True               False
# 1                 False  ...               True               False
# 2                 False  ...               True               False
# 3                 False  ...              False               False
# 4                 False  ...               True               False
# 5                 False  ...               True               False
# 6                 False  ...               True               False
# 7                 False  ...               True               False
# 8                 False  ...              False               False
# 9                 False  ...               True               False
#
#    GarageType_BuiltIn  GarageType_CarPort  GarageType_Detchd  \
# 0               False               False              False
# 1               False               False              False
# 2               False               False              False
# 3               False               False               True
# 4               False               False              False
# 5               False               False              False
# 6               False               False              False
# 7               False               False              False
# 8               False               False               True
# 9               False               False              False
#
#    SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# 0                  False                 False                 False
# 1                  False                 False                 False
# 2                  False                 False                 False
# 3                  False                 False                 False
# 4                  False                 False                 False
# 5                  False                 False                 False
# 6                  False                 False                 False
# 7                  False                 False                 False
# 8                  False                 False                 False
# 9                  False                 False                 False
#
#    SaleCondition_Normal  SaleCondition_Partial
# 0                  True                  False
# 1                  True                  False
# 2                  True                  False
# 3                 False                  False
# 4                  True                  False
# 5                  True                  False
# 6                  True                  False
# 7                  True                  False
# 8                 False                  False
# 9                  True                  False
#
# [10 rows x 47 columns]

# %%
missing_values = encoded_df.isnull().sum()
encoded_df.head(), missing_values
# Out:
# (   OverallQual  GrLivArea  TotRmsAbvGrd  LotArea  YearBuilt  SalePrice  \
#  0            7       1710             8     8450       2003     208500
#  1            6       1262             6     9600       1976     181500
#  2            7       1786             6    11250       2001     223500
#  3            7       1717             7     9550       1915     140000
#  4            8       2198             9    14260       2000     250000
#
#     Neighborhood_Blueste  Neighborhood_BrDale  Neighborhood_BrkSide  \
#  0                 False                False                 False
#  1                 False                False                 False
#  2                 False                False                 False
#  3                 False                False                 False
#  4                 False                False                 False
#
#     Neighborhood_ClearCr  ...  GarageType_Attchd  GarageType_Basment  \
#  0                 False  ...               True               False
#  1                 False  ...               True               False
#  2                 False  ...               True               False
#  3                 False  ...              False               False
#  4                 False  ...               True               False
#
#     GarageType_BuiltIn  GarageType_CarPort  GarageType_Detchd  \
#  0               False               False              False
#  1               False               False              False
#  2               False               False              False
#  3               False               False               True
#  4               False               False              False
#
#     SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
#  0                  False                 False                 False
#  1                  False                 False                 False
#  2                  False                 False                 False
#  3                  False                 False                 False
#  4                  False                 False                 False
#
#     SaleCondition_Normal  SaleCondition_Partial
#  0                  True                  False
#  1                  True                  False
#  2                  True                  False
#  3                 False                  False
#  4                  True                  False
#
#  [5 rows x 47 columns],
#  OverallQual              0
#  GrLivArea                0
#  TotRmsAbvGrd             0
#  LotArea                  0
#  YearBuilt                0
#  SalePrice                0
#  Neighborhood_Blueste     0
#  Neighborhood_BrDale      0
#  Neighborhood_BrkSide     0
#  Neighborhood_ClearCr     0
#  Neighborhood_CollgCr     0
#  Neighborhood_Crawfor     0
#  Neighborhood_Edwards     0
#  Neighborhood_Gilbert     0
#  Neighborhood_IDOTRR      0
#  Neighborhood_MeadowV     0
#  Neighborhood_Mitchel     0
#  Neighborhood_NAmes       0
#  Neighborhood_NPkVill     0
#  Neighborhood_NWAmes      0
#  Neighborhood_NoRidge     0
#  Neighborhood_NridgHt     0
#  Neighborhood_OldTown     0
#  Neighborhood_SWISU       0
#  Neighborhood_Sawyer      0
#  Neighborhood_SawyerW     0
#  Neighborhood_Somerst     0
#  Neighborhood_StoneBr     0
#  Neighborhood_Timber      0
#  Neighborhood_Veenker     0
#  HouseStyle_1.5Unf        0
#  HouseStyle_1Story        0
#  HouseStyle_2.5Fin        0
#  HouseStyle_2.5Unf        0
#  HouseStyle_2Story        0
#  HouseStyle_SFoyer        0
#  HouseStyle_SLvl          0
#  GarageType_Attchd        0
#  GarageType_Basment       0
#  GarageType_BuiltIn       0
#  GarageType_CarPort       0
#  GarageType_Detchd        0
#  SaleCondition_AdjLand    0
#  SaleCondition_Alloca     0
#  SaleCondition_Family     0
#  SaleCondition_Normal     0
#  SaleCondition_Partial    0
#  dtype: int64)

# %% [markdown]
# ## Now we clear missing values

# %% [markdown]
# # Write a custom function that will convert from categorical to numeric
# def convert_data(data) # the input must be one featuer and it should return corresponding transformed data

# %%
def convert_data(data):
    if data.dtype == 'object':
        return pd.get_dummies(data, drop_first=True)
    else:
        return data

# %%
transformed_data = convert_data(df['GarageType'])
print(transformed_data.head(10))
# Out:
#    Attchd  Basment  BuiltIn  CarPort  Detchd
# 0    True    False    False    False   False
# 1    True    False    False    False   False
# 2    True    False    False    False   False
# 3   False    False    False    False    True
# 4    True    False    False    False   False
# 5    True    False    False    False   False
# 6    True    False    False    False   False
# 7    True    False    False    False   False
# 8   False    False    False    False    True
# 9    True    False    False    False   False

# %% [markdown]
# # Now that we cleaned the data and already transformed
# # Check data distribution of data to know they should be normalized/scaled or not
# # in this case, we normally more foucs on the original numeric data instead of transformed numeric numbers.

# %%
import matplotlib.pyplot as plt
df['OverallCond'].hist(bins=10, edgecolor='black', figsize=(8, 6))
plt.title('Distribution of Overall Condition')
plt.xlabel('Overall Condition')
plt.ylabel('Frequency')
plt.show()

# %%
# let's find the variance and mean of OverallCond
df['OverallCond'].var()
# Out:
# 1.2383223637883065

# %%
df['OverallCond'].mean()
# Out:
# 5.575342465753424

# %% [markdown]
# Interpretation:<br>
# Low variance relative to mean → Data is less dispersed.<br>
# High variance relative to mean → Data is more spread out.<br>
# <hr>
# Should You Normalize?
# If variance is significantly less than the mean, the data is already relatively compact, and normalization may not be necessary.<br>
# However, if you're using models that are sensitive to scale (e.g., k-NN, SVM, neural networks), standardization (z-score scaling) might still be beneficial.

# %% [markdown]
# #The variance is relatively small compared to the mean. It means data is less dispersed. Therefore, normalization is not necessary.

# %% [markdown]
# # Lets check all dispersion rate of all columns

# %%
numerical_columns = df.select_dtypes(include=['number']).columns

mean_values = df[numerical_columns].mean()
variance_values = df[numerical_columns].var()

dispersion_rate = variance_values / mean_values

dispersion_data = pd.DataFrame({
    'Mean': mean_values,
    'Variance': variance_values,
    'Dispersion Rate': dispersion_rate
})

dispersion_data
# Out:
#                         Mean      Variance  Dispersion Rate
# Id                730.500000  1.777550e+05       243.333333
# MSSubClass         56.897260  1.789338e+03        31.448585
# LotFrontage        70.049958  5.897492e+02         8.418980
# LotArea         10516.828082  9.962565e+07      9472.975014
# OverallQual         6.099315  1.912679e+00         0.313589
# OverallCond         5.575342  1.238322e+00         0.222107
# YearBuilt        1971.267808  9.122154e+02         0.462756
# YearRemodAdd     1984.865753  4.262328e+02         0.214741
# MasVnrArea        103.685262  3.278497e+04       316.197024
# BsmtFinSF1        443.639726  2.080255e+05       468.906314
# BsmtFinSF2         46.549315  2.602391e+04       559.061025
# BsmtUnfSF         567.240411  1.952464e+05       344.203978
# TotalBsmtSF      1057.429452  1.924624e+05       182.009647
# 1stFlrSF         1162.626712  1.494501e+05       128.545197
# 2ndFlrSF          346.992466  1.905571e+05       549.167761
# LowQualFinSF        5.844521  2.364204e+03       404.516338
# GrLivArea        1515.463699  2.761296e+05       182.208016
# BsmtFullBath        0.425342  2.692682e-01         0.633062
# BsmtHalfBath        0.057534  5.700283e-02         0.990763
# FullBath            1.565068  3.035082e-01         0.193926
# HalfBath            0.382877  2.528937e-01         0.660510
# BedroomAbvGr        2.866438  6.654938e-01         0.232167
# KitchenAbvGr        1.046575  4.854892e-02         0.046388
# TotRmsAbvGrd        6.517808  2.641903e+00         0.405336
# Fireplaces          0.613014  4.155947e-01         0.677953
# GarageYrBlt      1978.506164  6.095825e+02         0.308102
# GarageCars          1.767123  5.584797e-01         0.316039
# GarageArea        472.980137  4.571251e+04        96.647843
# WoodDeckSF         94.244521  1.570981e+04       166.692061
# OpenPorchSF        46.660274  4.389861e+03        94.081342
# EnclosedPorch      21.954110  3.735550e+03       170.152668
# 3SsnPorch           3.409589  8.595059e+02       252.084888
# ScreenPorch        15.060959  3.108889e+03       206.420413
# PoolArea            2.758904  1.614216e+03       585.093185
# MiscVal            43.489041  2.461381e+05      5659.771961
# MoSold              6.321918  7.309595e+00         1.156231
# YrSold           2007.815753  1.763837e+00         0.000878
# SalePrice      180921.195890  6.311111e+09     34883.205548

# %%
selected_df.hist()
# Out:
# array([[<Axes: title={'center': 'OverallQual'}>,
#         <Axes: title={'center': 'GrLivArea'}>],
#        [<Axes: title={'center': 'TotRmsAbvGrd'}>,
#         <Axes: title={'center': 'LotArea'}>],
#        [<Axes: title={'center': 'YearBuilt'}>,
#         <Axes: title={'center': 'SalePrice'}>]], dtype=object)

# %%
selected_df.columns
# Out:
# Index(['OverallQual', 'GrLivArea', 'TotRmsAbvGrd', 'LotArea', 'YearBuilt',
#        'Neighborhood', 'HouseStyle', 'GarageType', 'SaleCondition',
#        'SalePrice'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler_std = StandardScaler()
scaler_mm = MinMaxScaler()

numerical_columns = ['OverallQual', 'GrLivArea', 'TotRmsAbvGrd', 'LotArea', 'YearBuilt', 'SalePrice']

scaled_df = selected_df.copy()

# StandardScaler
scaled_df[numerical_columns] = scaler_std.fit_transform(scaled_df[numerical_columns])

#MinMaxScaler
scaled_df[['LotArea', 'SalePrice']] = scaler_mm.fit_transform(scaled_df[['LotArea', 'SalePrice']])

scaled_df = pd.get_dummies(scaled_df, columns=['Neighborhood', 'HouseStyle', 'GarageType', 'SaleCondition'], drop_first=True)

scaled_df.head()
# Out:
#    OverallQual  GrLivArea  TotRmsAbvGrd   LotArea  YearBuilt  SalePrice  \
# 0     0.651479   0.370333      0.912210  0.033420   1.050994   0.241078
# 1    -0.071836  -0.482512     -0.318683  0.038795   0.156734   0.203583
# 2     0.651479   0.515013     -0.318683  0.046507   0.984752   0.261908
# 3     0.651479   0.383659      0.296763  0.038561  -1.863632   0.145952
# 4     1.374795   1.299326      1.527656  0.060576   0.951632   0.298709
#
#    Neighborhood_Blueste  Neighborhood_BrDale  Neighborhood_BrkSide  \
# 0                 False                False                 False
# 1                 False                False                 False
# 2                 False                False                 False
# 3                 False                False                 False
# 4                 False                False                 False
#
#    Neighborhood_ClearCr  ...  GarageType_Attchd  GarageType_Basment  \
# 0                 False  ...               True               False
# 1                 False  ...               True               False
# 2                 False  ...               True               False
# 3                 False  ...              False               False
# 4                 False  ...               True               False
#
#    GarageType_BuiltIn  GarageType_CarPort  GarageType_Detchd  \
# 0               False               False              False
# 1               False               False              False
# 2               False               False              False
# 3               False               False               True
# 4               False               False              False
#
#    SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# 0                  False                 False                 False
# 1                  False                 False                 False
# 2                  False                 False                 False
# 3                  False                 False                 False
# 4                  False                 False                 False
#
#    SaleCondition_Normal  SaleCondition_Partial
# 0                  True                  False
# 1                  True                  False
# 2                  True                  False
# 3                 False                  False
# 4                  True                  False
#
# [5 rows x 47 columns]

# %%
scaled_df.hist()
# Out:
# array([[<Axes: title={'center': 'OverallQual'}>,
#         <Axes: title={'center': 'GrLivArea'}>],
#        [<Axes: title={'center': 'TotRmsAbvGrd'}>,
#         <Axes: title={'center': 'LotArea'}>],
#        [<Axes: title={'center': 'YearBuilt'}>,
#         <Axes: title={'center': 'SalePrice'}>]], dtype=object)
